# %%
#pip install lightkurve

# %%
import matplotlib.pyplot as plt
import lightkurve as lk

# %% [markdown]
# ## TEST RUN

# %%
TIC = 'TIC 284475976'

# %%
sector_data = lk.search_lightcurve(TIC, author = 'SPOC',sector = 23)

# %%
sector_data
# Out:
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 23 2020   SPOC     120   284475976      0.0

# %%
lc = sector_data.download() #downloading light curve data

# %%
lc.plot() #plotting light curve
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %% [markdown]
# ## for Observational Technique Target Proposal

# %% [markdown]
# ## TARGET 1 RA: 173.92634510763125 Dec: +35.573109570048594

# %% [markdown]
# ### We can assume T1 has a period larger than 22 days.

# %%
TIC1 = 'TIC 101625340' # distance = 2.59 arsec

# %%
sector_data1 = lk.search_lightcurve(TIC1)
sector_data1
# Out:
# SearchResult containing 6 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 22 2020      SPOC     120   101625340      0.0
#   1 TESS Sector 49 2022      SPOC     120   101625340      0.0
#   2 TESS Sector 22 2020 TESS-SPOC    1800   101625340      0.0
#   3 TESS Sector 49 2022 TESS-SPOC     600   101625340      0.0
#   4 TESS Sector 22 2020       QLP    1800   101625340      0.0
#   5 TESS Sector 49 2022       QLP     600   101625340      0.0

# %%
sector_data1 = lk.search_lightcurve(TIC1, author = 'SPOC', sector=22)
lc1 = sector_data1.download() #downloading light curve data

# %%
lc1.plot() #plotting light curve
plt.show()

# %% [markdown]
# ## TARGET 2 RA: 91.37515254235736 Dec: +60.819401063972606

# %%
TIC2 = 'TIC 71038757' # distance = 8.444 arcsec to target
sector_data2 = lk.search_lightcurve(TIC2)
sector_data2
# Out:
# SearchResult containing 13 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 19 2019      SPOC     120    71038757      0.0
#   1 TESS Sector 20 2019      SPOC     120    71038757      0.0
#   2 TESS Sector 59 2022      SPOC     120    71038757      0.0
#   3 TESS Sector 60 2022      SPOC     120    71038757      0.0
#   4 TESS Sector 19 2019 TESS-SPOC    1800    71038757      0.0
#   5 TESS Sector 20 2019 TESS-SPOC    1800    71038757      0.0
#   6 TESS Sector 59 2022 TESS-SPOC     200    71038757      0.0
#   7 TESS Sector 60 2022 TESS-SPOC     200    71038757      0.0
#   8 TESS Sector 19 2019       QLP    1800    71038757      0.0
#   9 TESS Sector 20 2019       QLP    1800    71038757      0.0
#  10 TESS Sector 59 2022       QLP     200    71038757      0.0
# ...

# %%
sector_data2 = lk.search_lightcurve(TIC2, author = 'SPOC', sector=19)
lc2 = sector_data2.download() #downloading light curve data
lc2.plot() #plotting light curve
plt.show()

# %% [markdown]
# ## TARGET 3 RA: 257.3834721191679 Dec: +43.680105808986085

# %% [markdown]
# ### T3 has a period larger than 15?

# %%
TIC3 = 'TIC 219085795' #distance = 2.02arcsec
sector_data3 = lk.search_lightcurve(TIC3)
sector_data3
# Out:
# SearchResult containing 30 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 26 2020   SPOC     120   219085795      0.0
#   1 TESS Sector 25 2020   SPOC     120   219085795      0.0
#   2 TESS Sector 24 2020   SPOC     120   219085795      0.0
#   3 TESS Sector 53 2022   SPOC      20   219085795      0.0
#   4 TESS Sector 52 2022   SPOC      20   219085795      0.0
#   5 TESS Sector 51 2022   SPOC      20   219085795      0.0
#   6 TESS Sector 53 2022   SPOC     120   219085795      0.0
#   7 TESS Sector 52 2022   SPOC     120   219085795      0.0
#   8 TESS Sector 51 2022   SPOC     120   219085795      0.0
# ...            ...  ...    ...     ...         ...      ...
#  20 TESS Sector 24 2020    QLP    1800   219085795      0.0
#  21 TESS Sector 53 2022    QLP     600   219085795      0.0
# ...

# %%
sector_data3 = lk.search_lightcurve(TIC3, author = 'SPOC', sector=26)
lc3 = sector_data3.download() #downloading light curve data
lc3.plot() #plotting light curve
plt.show()

# %% [markdown]
# ## TARGET 4 RA: 183.93308097127309 Dec: +52.51643832583794

# %%
TIC4 = 'TIC 416538823' #distance = 0 arcsec
sector_data4 = lk.search_lightcurve(TIC4)
sector_data4
# Out:
# SearchResult containing 23 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 15 2019      SPOC     120   416538823      0.0
#   1 TESS Sector 22 2020      SPOC     120   416538823      0.0
#   2 TESS Sector 49 2022      SPOC      20   416538823      0.0
#   3 TESS Sector 48 2022      SPOC      20   416538823      0.0
#   4 TESS Sector 49 2022      SPOC     120   416538823      0.0
#   5 TESS Sector 48 2022      SPOC     120   416538823      0.0
#   6 TESS Sector 75 2024      SPOC      20   416538823      0.0
#   7 TESS Sector 76 2024      SPOC      20   416538823      0.0
#   8 TESS Sector 76 2024      SPOC     120   416538823      0.0
# ...            ...  ...       ...     ...         ...      ...
#  13 TESS Sector 49 2022 TESS-SPOC     600   416538823      0.0
# ...

# %%
sector_data4 = lk.search_lightcurve(TIC4, author = 'SPOC', sector=15)
lc4 = sector_data4.download() #downloading light curve data
lc4.plot() #plotting light curve
plt.show()

# %% [markdown]
# ## TARGET 5 RA: 201.7206797854293 Dec: +45.545520529192935

# %% [markdown]
# ### T5 has a period larger than 20 days? (It has good light curve, might use for the proposal)

# %%
TIC5 = 'TIC 446175401' #distance = 0 arcsec
sector_data5 = lk.search_lightcurve(TIC5)
sector_data5
# Out:
# SearchResult containing 19 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 16 2019      SPOC     120   446175401      0.0
#   1 TESS Sector 23 2020      SPOC     120   446175401      0.0
#   2 TESS Sector 22 2020      SPOC     120   446175401      0.0
#   3 TESS Sector 49 2022      SPOC      20   446175401      0.0
#   4 TESS Sector 49 2022      SPOC     120   446175401      0.0
#   5 TESS Sector 76 2024      SPOC     120   446175401      0.0
#   6 TESS Sector 16 2019 TESS-SPOC    1800   446175401      0.0
#   7 TESS Sector 22 2020 TESS-SPOC    1800   446175401      0.0
#   8 TESS Sector 23 2020 TESS-SPOC    1800   446175401      0.0
#   9 TESS Sector 49 2022 TESS-SPOC     600   446175401      0.0
#  10 TESS Sector 16 2019       QLP    1800   446175401      0.0
# ...

# %%
sector_data5 = lk.search_lightcurve(TIC5, author = 'SPOC', sector=16)
lc5 = sector_data5.download() #downloading light curve data
lc5.plot() #plotting light curve
plt.show()

# %% [markdown]
# ## TARGET 6 RA: 301.25028584217137 Dec: +54.43021426747369

# %%
TIC6 = 'TIC 1978650244' #distance = 4.63 arcsec
sector_data6 = lk.search_lightcurve(TIC6)
sector_data6
# Out:
# SearchResult containing 2 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 56 2022      SPOC     120  1978650244      0.0
#   1 TESS Sector 56 2022 TESS-SPOC     200  1978650244      0.0

# %%
sector_data6 = lk.search_lightcurve(TIC6, author = 'SPOC', sector=56)
lc6 = sector_data6.download() #downloading light curve data
lc6.plot() #plotting light curve
plt.show()

# %% [markdown]
# ## TARGET 7 RA: 352.3762764481757 Dec: -1.03600386270034

# %% [markdown]
# ### T7 has a period larger than 17 days but is this just a binary?

# %%
TIC7 = 'TIC 301329955' # distance = 0 arcsec

# %%
sector_data7 = lk.search_lightcurve(TIC7)

# %%
sector_data7
# Out:
# SearchResult containing 7 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 42 2021      SPOC     120   301329955      0.0
#   1 TESS Sector 70 2023      SPOC      20   301329955      0.0
#   2 TESS Sector 70 2023      SPOC     120   301329955      0.0
#   3 TESS Sector 42 2021 TESS-SPOC     600   301329955      0.0
#   4 TESS Sector 70 2023 TESS-SPOC     200   301329955      0.0
#   5 TESS Sector 42 2021       QLP     600   301329955      0.0
#   6 TESS Sector 70 2023       QLP     200   301329955      0.0

# %%
sector_data7 = lk.search_lightcurve(TIC7, author = 'SPOC', sector=70)

# %%
lc7 = sector_data7.download() #downloading light curve data
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/lightkurve/search.py:424: LightkurveWarning: Warning: 2 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   warnings.warn(

# %%
lc7.plot() #plotting light curve
plt.show()

# %% [markdown]
# ## TARGET 8 RA: 93.93372269692969 Dec: -12.791414879076138

# %% [markdown]
# ### T8 has a period about 8 days, but it is also very polluted...

# %%
TIC8 = 'TIC 33943026' #distance = 225 arcsec very unlikely no use
sector_data8 = lk.search_lightcurve(TIC8)
sector_data8
# Out:
# SearchResult containing 14 data products.
#
#  #     mission     year       author      exptime target_name distance
#                                              s                 arcsec
# --- -------------- ---- ----------------- ------- ----------- --------
#   0 TESS Sector 06 2018              SPOC     120    33943026      0.0
#   1 TESS Sector 33 2020              SPOC     120    33943026      0.0
#   2 TESS Sector 06 2018         TESS-SPOC    1800    33943026      0.0
#   3 TESS Sector 33 2020         TESS-SPOC     600    33943026      0.0
#   4 TESS Sector 06 2018               QLP    1800    33943026      0.0
#   5 TESS Sector 33 2020               QLP     600    33943026      0.0
#   6 TESS Sector 87 2024               QLP     200    33943026      0.0
#   7 TESS Sector 06 2018             TASOC     120    33943026      0.0
#   8 TESS Sector 06 2018             CDIPS    1800    33943026      0.0
#   9 TESS Sector 06 2018 GSFC-ELEANOR-LITE    1800    33943026      0.0
# ...

# %%
sector_data8 = lk.search_lightcurve(TIC8, author = 'SPOC', sector= 6)
lc8 = sector_data8.download() #downloading light curve data
lc8.plot() #plotting light curve
plt.show()

# %% [markdown]
# ## TARGET 9 RA: 83.43563711932828 Dec: +1.9447191815123406

# %% [markdown]
# ### T9 has a period larger than 10?

# %%
TIC9 = 'TIC 220044948' #distance = 0 arcsec 
sector_data9 = lk.search_lightcurve(TIC9)
sector_data9
# Out:
# SearchResult containing 12 data products.
#
#  #     mission     year       author      exptime target_name distance
#                                              s                 arcsec
# --- -------------- ---- ----------------- ------- ----------- --------
#   0 TESS Sector 06 2018              SPOC     120   220044948      0.0
#   1 TESS Sector 32 2020              SPOC      20   220044948      0.0
#   2 TESS Sector 32 2020              SPOC     120   220044948      0.0
#   3 TESS Sector 06 2018         TESS-SPOC    1800   220044948      0.0
#   4 TESS Sector 32 2020         TESS-SPOC     600   220044948      0.0
#   5 TESS Sector 06 2018               QLP    1800   220044948      0.0
#   6 TESS Sector 32 2020               QLP     600   220044948      0.0
#   7 TESS Sector 06 2018             TASOC     120   220044948      0.0
#   8 TESS Sector 06 2018 GSFC-ELEANOR-LITE    1800   220044948      0.0
#   9 TESS Sector 06 2018             TASOC    1800   220044948      0.0
# ...

# %%
sector_data9 = lk.search_lightcurve(TIC9, author = 'SPOC', sector= 6)
lc9 = sector_data9.download() #downloading light curve data
lc9.plot() #plotting light curve
plt.show()

# %% [markdown]
# ## TARGET 10 RA: 197.21297743841944 Dec: +5.204216879125762

# %% [markdown]
# ### T10 has a period larger than 10

# %%
TIC10 = 'TIC 381726125' #distance = 6.08 arcsec
sector_data10 = lk.search_lightcurve(TIC10)
sector_data10
# Out:
# SearchResult containing 11 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 23 2020      SPOC     120   381726125      0.0
#   1 TESS Sector 46 2021      SPOC      20   381726125      0.0
#   2 TESS Sector 46 2021      SPOC     120   381726125      0.0
#   3 TESS Sector 50 2022      SPOC      20   381726125      0.0
#   4 TESS Sector 50 2022      SPOC     120   381726125      0.0
#   5 TESS Sector 23 2020 TESS-SPOC    1800   381726125      0.0
#   6 TESS Sector 46 2021 TESS-SPOC     600   381726125      0.0
#   7 TESS Sector 50 2022 TESS-SPOC     600   381726125      0.0
#   8 TESS Sector 23 2020       QLP    1800   381726125      0.0
#   9 TESS Sector 46 2021       QLP     600   381726125      0.0
#  10 TESS Sector 50 2022       QLP     600   381726125      0.0

# %%
sector_data10 = lk.search_lightcurve(TIC10, author = 'SPOC', sector=23)
lc10 = sector_data10.download() #downloading light curve data
lc10.plot() #plotting light curve
plt.show()

# %% [markdown]
# ## TARGET 11 RA: 276.59053098427415 Dec: +8.613677131548735

# %% [markdown]
# ### T11 has a period larger than 10? (in conclusive)

# %%
TIC11 = 'TIC 25933136' #distance = 3.24 arcsec
sector_data11 = lk.search_lightcurve(TIC11)
sector_data11
# Out:
# SearchResult containing 3 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 80 2024   SPOC      20    25933136      0.0
#   1 TESS Sector 80 2024   SPOC     120    25933136      0.0
#   2 TESS Sector 80 2024    QLP     200    25933136      0.0

# %%
sector_data11 = lk.search_lightcurve(TIC11, author = 'SPOC', sector=80)
lc11 = sector_data11.download() #downloading light curve data
lc11.plot() #plotting light curve
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/lightkurve/search.py:424: LightkurveWarning: Warning: 2 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   warnings.warn(

# %% [markdown]
# ## TARGET 12 RA: 65.27338195414822 Dec: -48.65433424724288

# %% [markdown]
# ### T12 has a period larger than 12?
#
# #### Smaller MS orbiting? (there are dips, meaning the obect beng observred loses light, a lot of light wrt the system ~400 e-/s)

# %%
TIC12 = 'TIC 219244444' #distance = 3.51 arcsec
sector_data12 = lk.search_lightcurve(TIC12)
sector_data12
# Out:
# SearchResult containing 34 data products.
#
#  #     mission     year       author      exptime target_name distance
#                                              s                 arcsec
# --- -------------- ---- ----------------- ------- ----------- --------
#   0 TESS Sector 05 2018              SPOC     120   219244444      0.0
#   1 TESS Sector 04 2018              SPOC     120   219244444      0.0
#   2 TESS Sector 03 2018              SPOC     120   219244444      0.0
#   3 TESS Sector 30 2020              SPOC      20   219244444      0.0
#   4 TESS Sector 32 2020              SPOC      20   219244444      0.0
#   5 TESS Sector 32 2020              SPOC     120   219244444      0.0
#   6 TESS Sector 30 2020              SPOC     120   219244444      0.0
#   7 TESS Sector 03 2018         TESS-SPOC    1800   219244444      0.0
#   8 TESS Sector 05 2018         TESS-SPOC    1800   219244444      0.0
# ...            ...  ...               ...     ...         ...      ...
# ...

# %%
sector_data12 = lk.search_lightcurve(TIC12, author = 'SPOC', sector= 5)
lc12 = sector_data12.download() #downloading light curve data
lc12.plot() #plotting light curve
plt.show()

# %% [markdown]
# ## TARGET 13 RA: 282.0832933709044 Dec: -68.93164960388835

# %% [markdown]
# ### T13 inclonclusive, too little light that the SNR is very small (assume 10days min)

# %%
TIC13 = 'TIC 324899538' #distance = 15.8 arcsec
sector_data13 = lk.search_lightcurve(TIC13)
sector_data13
# Out:
# SearchResult containing 3 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 13 2019      SPOC     120   324899538      0.0
#   1 TESS Sector 13 2019 TESS-SPOC    1800   324899538      0.0
#   2 TESS Sector 67 2023 TESS-SPOC     200   324899538      0.0

# %%
sector_data13 = lk.search_lightcurve(TIC13, author = 'SPOC', sector= 13)
lc13 = sector_data13.download() #downloading light curve data
lc13.plot() #plotting light curve
plt.show()
